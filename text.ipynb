# %%
import nltk

# %%
from google.colab import files
from google.colab import files

uploaded = files.upload()
# !pip install nltk scikit-learn
# please upload the NLP_Data.csv file attached
# Out:
#      <input type="file" id="files-cbbc90cb-5036-4dc3-8c46-4edb7c25996b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cbbc90cb-5036-4dc3-8c46-4edb7c25996b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Import necessary libraries
import nltk
nltk.download('stopwords')
import nltk
nltk.download('punkt')
import nltk
nltk.download('wordnet')
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
# Step 1: Text cleaning
def clean_text(text):

    if isinstance(text, str):
        text = text.lower()
        text = ''.join([char for char in text if char.isalpha() or char.isspace()])
        stop_words = set(stopwords.words('english'))
        words = word_tokenize(text)
        text = ' '.join([word for word in words if word not in stop_words])
    else:
        text = ''
    return text

# Step 2: Stemming
def stem_text(text):
    stemmer = PorterStemmer()
    words = word_tokenize(text)
    stemmed_words = [stemmer.stem(word) for word in words]
    return ' '.join(stemmed_words)
# Step 3: Lemmatization
def lemmatize_text(text):
    lemmatizer = WordNetLemmatizer()
    words = word_tokenize(text)
    lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
    return ' '.join(lemmatized_words)

# Step 4: Vectorization (using TF-IDF)
def vectorize_text(texts):
    vectorizer = TfidfVectorizer(max_features=1000)
    X = vectorizer.fit_transform(texts)
    return X

# Step 5: Classification
def classify_text(X, y):

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)
    classifier = MultinomialNB()
    classifier.fit(X_train, y_train)
    y_pred = classifier.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    return accuracy

if __name__ == '__main__':
    # Load data from CSV file
    df = pd.read_csv('NLP_Data.csv')

    # Print some data from the CSV file
    print(df.head())
    # Step 1: Clean the text
    df['Cleaned_Description'] = df['Description of the Grievance'].apply(clean_text)
    print(df['Cleaned_Description'].head())

    # Step 2: Stem the text
    df['Stemmed_Description'] = df['Cleaned_Description'].apply(stem_text)
    print(df['Stemmed_Description'].head())

    # Step 3: Lemmatize the text
    df['Lemmatized_Description'] = df['Cleaned_Description'].apply(lemmatize_text)
    print(df['Lemmatized_Description'].head())

    # Drop rows with missing values in the target variable 'Grievance Category'
    df = df.dropna(subset=['Grievance Category'])

    # Step 4: Vectorize the text
    X = vectorize_text(df['Lemmatized_Description'])
    y = df['Grievance Category']

    # Perform classification and print accuracy
    accuracy = classify_text(X, y)
    print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
#                         Description of the Grievance  \
# 0  concerns regarding laboratory tests being bill...
# 1                       dassatifaction with provider
# 2              Dissatisafaction with delay in care.
# 3  Dissatisafaction with Dental provider way of c...
# 4  Dissatisfaction for not being informed he had ...
#
#           Grievance Category                 Grievance SubCategory
# 0  Billing/Financial Dispute                 Provider Claim Issues
# 1         Quality Of Service  Not Satisfied With Provider Services
# 2    Access And Availability                              Pharmacy
# 3         Quality Of Service  Not Satisfied With Provider Services
# 4  Billing/Financial Dispute                       Balance Billing
# 0     concerns regarding laboratory tests billed twice
# 1                              dassatifaction provider
# 2                          dissatisafaction delay care
# 3    dissatisafaction dental provider way conductin...
# ...
